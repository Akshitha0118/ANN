# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.20.0'

# %%
dataset = pd.read_csv(r'C:\Users\Admin\Downloads\Churn_Modelling.csv')
X=dataset.iloc[:,3:-1].values
y=dataset.iloc[:,-1].values

# %%
# Encoding categorical data
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X[:,2] = le.fit_transform(X[:,2])

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct=ColumnTransformer(transformers=[['encode',OneHotEncoder(),[1]]],remainder='passthrough')
X=np.array(ct.fit_transform(X))

# %%
X
# Out:
# array([[0.0, 1.0, 0.0, ..., 1, 1, 101348.88],
#        [1.0, 0.0, 0.0, ..., 0, 1, 112542.58],
#        [0.0, 1.0, 0.0, ..., 1, 0, 113931.57],
#        ...,
#        [0.0, 1.0, 0.0, ..., 0, 1, 42085.58],
#        [0.0, 0.0, 1.0, ..., 1, 0, 92888.52],
#        [0.0, 1.0, 0.0, ..., 1, 0, 38190.78]],
#       shape=(10000, 12), dtype=object)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X=sc.fit_transform(X)

# %%
X
# Out:
# array([[-0.57380915,  0.99720391, -0.57873591, ...,  0.64609167,
#          0.97024255,  0.02188649],
#        [ 1.74273971, -1.00280393, -0.57873591, ..., -1.54776799,
#          0.97024255,  0.21653375],
#        [-0.57380915,  0.99720391, -0.57873591, ...,  0.64609167,
#         -1.03067011,  0.2406869 ],
#        ...,
#        [-0.57380915,  0.99720391, -0.57873591, ..., -1.54776799,
#          0.97024255, -1.00864308],
#        [-0.57380915, -1.00280393,  1.72790383, ...,  0.64609167,
#         -1.03067011, -0.12523071],
#        [-0.57380915,  0.99720391, -0.57873591, ...,  0.64609167,
#         -1.03067011, -1.07636976]], shape=(10000, 12))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# # ANN

# %%
ann = tf.keras.models.Sequential() ## Establish layer one afterto anther

# %%
ann.add(tf.keras.layers.Dense(units=6)) # input layer

# %%
ann.add(tf.keras.layers.Dense(units=6,activation='relu'))

# %%
ann.add(tf.keras.layers.Dense(units=5,activation='relu'))

# %%
ann.add(tf.keras.layers.Dense(units=1,activation='sigmoid'))

# %%
ann.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accurray'])

# %%
ann.fit(X_train,y_train,batch_size=32,epochs=20)
# Out:
# Epoch 1/20
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 ann.fit(X_train,y_train,batch_size=32,epochs=20)
#
# File c:\Users\Admin\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\Admin\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:153, in TensorFlowTrainer._make_function.<locals>.multi_step_on_iterator(iterator)
#     150 @tf.autograph.experimental.do_not_convert
#     151 def multi_step_on_iterator(iterator):
#     152     if self.steps_per_execution == 1:
# --> 153         return tf.experimental.Optional.from_value(
#     154             one_step_on_data(iterator.get_next())
#     155         )
#     157     # the spec is set lazily during the tracing of `tf.while_loop`
#     158     empty_outputs = tf.experimental.Optional.empty(None)
#
# ValueError: Attr 'Toutput_types' of 'OptionalFromValue' Op passed list of length 0 less than minimum 1.
